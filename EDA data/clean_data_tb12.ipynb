# %%
import pandas as pd
import os

# %%
df = pd.read_csv(r'../raw_data/Table12_TFW_Positions_Requested_LMIAs_Province_2016_2023.csv', encoding='ISO-8859-1',skiprows=1)
df.tail(20)
# Out:
#                                    Province/Territory     2016     2017  \
# 1                                Prince Edward Island      979    1,246
# 2                                         Nova Scotia    2,531    3,504
# 3                                       New Brunswick    1,648    1,664
# 4                                              Quebec   17,107   20,934
# 5                                             Ontario   36,729   44,685
# 6                                            Manitoba    1,455    1,610
# 7                                        Saskatchewan    1,256    1,272
# 8                                             Alberta   13,115   10,650
# 9                                    British Columbia   26,117   26,608
# 10                                              Yukon      126      129
# 11                              Northwest Territories       79       68
# 12                                            Nunavut      156       44
# ...

# %%
df = df.iloc[:-7]

# %%
df.tail()
# Out:
#        Province/Territory     2016     2017     2018     2019     2020  \
# 9        British Columbia   26,117   26,608   37,466   31,815   35,407
# 10                  Yukon      126      129      123      146       61
# 11  Northwest Territories       79       68       64       58       28
# 12                Nunavut      156       44      141      136       46
# 13                 Canada  103,232  113,603  131,748  132,472  140,014
#
#        2021     2022     2023
# 9    38,076   48,690   64,923
# 10      138      168      167
# 11       76      105      211
# 12       84       77      146
# 13  158,724  222,078  277,095

# %%
df
# Out:
#            Province/Territory     2016     2017     2018     2019     2020  \
# 0   Newfoundland and Labrador    1,912    1,175      533      864      744
# 1        Prince Edward Island      979    1,246    1,066    1,413    2,008
# 2                 Nova Scotia    2,531    3,504    3,134    3,187    3,663
# 3               New Brunswick    1,648    1,664    1,936    2,140    3,205
# 4                      Quebec   17,107   20,934   28,046   32,905   33,964
# 5                     Ontario   36,729   44,685   42,247   43,862   47,132
# 6                    Manitoba    1,455    1,610    2,106    1,978    1,880
# 7                Saskatchewan    1,256    1,272    1,622    1,521    1,344
# 8                     Alberta   13,115   10,650   13,264   12,447   10,532
# 9            British Columbia   26,117   26,608   37,466   31,815   35,407
# 10                      Yukon      126      129      123      146       61
# ...

# %%
df.rename(columns={'Province/Territory':'Province_Territory'}, inplace=True)

# %%
df
# Out:
#            Province_Territory     2016     2017     2018     2019     2020  \
# 0   Newfoundland and Labrador    1,912    1,175      533      864      744
# 1        Prince Edward Island      979    1,246    1,066    1,413    2,008
# 2                 Nova Scotia    2,531    3,504    3,134    3,187    3,663
# 3               New Brunswick    1,648    1,664    1,936    2,140    3,205
# 4                      Quebec   17,107   20,934   28,046   32,905   33,964
# 5                     Ontario   36,729   44,685   42,247   43,862   47,132
# 6                    Manitoba    1,455    1,610    2,106    1,978    1,880
# 7                Saskatchewan    1,256    1,272    1,622    1,521    1,344
# 8                     Alberta   13,115   10,650   13,264   12,447   10,532
# 9            British Columbia   26,117   26,608   37,466   31,815   35,407
# 10                      Yukon      126      129      123      146       61
# ...

# %%
#Define the dedicated folder path
folder_path = 'C:/Users/Johnn/Desktop/Data Engineer project/LMIA_evaluation_project/clean_data'
csv_file = os.path.join(folder_path, 'Table12_TFW_Positions_Requested_LMIAs_Province_2016_2023_cleaned.csv')

# Save the DataFrame to CSV
df.to_csv(csv_file, index=False)
