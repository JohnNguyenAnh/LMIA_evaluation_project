# %%
import pandas as pd
import os

# %%
#import table 5 file
df = pd.read_csv(r'../raw_data/Table17_Positive_LMIAs_By_NOC_SkillType_Province_2016_2023.csv', encoding='ISO-8859-1')
df.tail(20)
# Out:
#     Number of Positive Labour Market Impact Assessments (LMIA) by National Occupational Classification - 2011 (NOC) Occupational Skill Type, and Province/Territory   \
# 183                           Occupational Skill Type
# 184                                                NaN
# 185                        0 - Management occupations
# 186  1 - Business, finance and administration occup...
# 187  2 - Natural and applied sciences and related o...
# 188                            3 - Health occupations
# 189  4 - Occupations in education, law and social, ...
# 190  5 - Occupations in art, culture, recreation an...
# 191                 6 - Sales and service occupations
# 192  7 - Trades, transport and equipment operators ...
# 193  8 - Natural resources, agriculture and related...
# 194    9 - Occupations in manufacturing and utilities
# 195                                      Nunavut Total
# 196                                             Notes:
# 197  1. The source for all information in this repo...
# 198   2. As of the publication of 2023 annual data ...
# 199  3. Effective November 2016, NOC 2011 is being ...
# 200  4. Each LMIA application submitted is restrict...
# 201  5. The LMIA System tracks TFW positions only, ...
# 202  6. The numbers appearing in this release may d...
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 183        NaN        NaN        NaN        NaN        NaN        NaN
# 184       2016       2017       2018       2019       2020       2021
# 185          2          1          4          0          1          0
# 186          3          0          1          1          1          3
# 187         12          1         25          7          8          8
# 188          2          1          1          0          0          1
# 189          6          6         10          2          2          2
# 190          7          1          6          1          0          2
# 191         83         15         38         33          4          6
# 192         15          2         19         16          7         21
# 193          0          0          0          0          0          0
# 194          0          0          0          0          0          0
# 195        130         27        104         60         23         43
# 196        NaN        NaN        NaN        NaN        NaN        NaN
# 197        NaN        NaN        NaN        NaN        NaN        NaN
# 198        NaN        NaN        NaN        NaN        NaN        NaN
# 199        NaN        NaN        NaN        NaN        NaN        NaN
# 200        NaN        NaN        NaN        NaN        NaN        NaN
# 201        NaN        NaN        NaN        NaN        NaN        NaN
# 202        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Unnamed: 7 Unnamed: 8
# 183        NaN        NaN
# 184       2022       2023
# 185          2          0
# 186          1          1
# 187          7         23
# 188          1          0
# 189          1          1
# 190          0          0
# 191         21         29
# 192          8         28
# 193          0          0
# 194          0          0
# 195         41         82
# 196        NaN        NaN
# 197        NaN        NaN
# 198        NaN        NaN
# 199        NaN        NaN
# 200        NaN        NaN
# 201        NaN        NaN
# 202        NaN        NaN

# %%
df = df.iloc[:-7]
df.tail()
# Out:
#     Number of Positive Labour Market Impact Assessments (LMIA) by National Occupational Classification - 2011 (NOC) Occupational Skill Type, and Province/Territory   \
# 191                 6 - Sales and service occupations
# 192  7 - Trades, transport and equipment operators ...
# 193  8 - Natural resources, agriculture and related...
# 194    9 - Occupations in manufacturing and utilities
# 195                                      Nunavut Total
#
#     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 191         83         15         38         33          4          6
# 192         15          2         19         16          7         21
# 193          0          0          0          0          0          0
# 194          0          0          0          0          0          0
# 195        130         27        104         60         23         43
#
#     Unnamed: 7 Unnamed: 8
# 191         21         29
# 192          8         28
# 193          0          0
# 194          0          0
# 195         41         82

# %%
df.head(15)
# Out:
#    Number of Positive Labour Market Impact Assessments (LMIA) by National Occupational Classification - 2011 (NOC) Occupational Skill Type, and Province/Territory   \
# 0                                              Canada
# 1                            Occupational Skill Type
# 2                                                 NaN
# 3                         0 - Management occupations
# 4   1 - Business, finance and administration occup...
# 5   2 - Natural and applied sciences and related o...
# 6                             3 - Health occupations
# 7   4 - Occupations in education, law and social, ...
# 8   5 - Occupations in art, culture, recreation an...
# 9                  6 - Sales and service occupations
# 10  7 - Trades, transport and equipment operators ...
# 11  8 - Natural resources, agriculture and related...
# 12    9 - Occupations in manufacturing and utilities
# 13                                       Canada Total
# 14                          Newfoundland and Labrador
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2        2016       2017       2018       2019       2020       2021
# 3       1,834      1,701      1,452      2,180      2,646      2,569
# 4       1,065      1,196      1,153      2,492      2,887      2,499
# 5       3,350      3,238      3,465      5,003      4,200      5,360
# 6         617        478        401        682        869        972
# 7       6,797      7,458      9,003      7,153      4,451      5,515
# 8       4,132      2,777      2,378      2,377      1,172      1,296
# 9       6,013      6,841      6,286     11,271      9,987      9,894
# 10      3,090      3,447      3,131      6,143      5,607      5,719
# 11      8,332      8,344      9,430     11,037     11,243     12,192
# 12        249        344        403        805      1,143      1,140
# 13     35,479     35,824     37,102     49,144     44,207     47,157
# 14        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 7 Unnamed: 8
# 0         NaN        NaN
# 1         NaN        NaN
# 2        2022       2023
# 3       3,894      4,460
# 4       6,739     10,035
# 5       9,419      7,204
# 6       1,778      2,552
# 7       5,142      5,467
# 8       2,482      2,095
# 9      24,417     31,142
# 10     13,286     14,689
# 11     15,146     15,252
# 12      3,206      3,252
# 13     85,514     96,159
# 14        NaN        NaN

# %%
# Define new column names in the desired order
new_column_names = ['Occupational_Skill_Type', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']

# Rename the columns by mapping the old names to the new names in order
df.columns = new_column_names

#  Remove rows that contain "Occupational Skill Level" adn Nan value (since these are summary rows)
df = df[~df['Occupational_Skill_Type'].str.contains('Occupational', na=True)]

# %%
df.head(20)
# Out:
#                               Occupational_Skill_Type    2016    2017    2018  \
# 0                                              Canada     NaN     NaN     NaN
# 3                         0 - Management occupations    1,834   1,701   1,452
# 4   1 - Business, finance and administration occup...   1,065   1,196   1,153
# 5   2 - Natural and applied sciences and related o...   3,350   3,238   3,465
# 6                             3 - Health occupations      617     478     401
# 7   4 - Occupations in education, law and social, ...   6,797   7,458   9,003
# 8   5 - Occupations in art, culture, recreation an...   4,132   2,777   2,378
# 9                  6 - Sales and service occupations    6,013   6,841   6,286
# 10  7 - Trades, transport and equipment operators ...   3,090   3,447   3,131
# 11  8 - Natural resources, agriculture and related...   8,332   8,344   9,430
# 12    9 - Occupations in manufacturing and utilities      249     344     403
# 13                                       Canada Total  35,479  35,824  37,102
# 14                          Newfoundland and Labrador     NaN     NaN     NaN
# 17                        0 - Management occupations       67      34      14
# 18  1 - Business, finance and administration occup...      14       6       5
# 19  2 - Natural and applied sciences and related o...     567     453      98
# 20                            3 - Health occupations       27      10       8
# 21  4 - Occupations in education, law and social, ...      25      13      11
# 22  5 - Occupations in art, culture, recreation an...      11       9       1
# 23                 6 - Sales and service occupations      117      77      29
#
#       2019    2020    2021    2022    2023
# 0      NaN     NaN     NaN     NaN     NaN
# 3    2,180   2,646   2,569   3,894   4,460
# 4    2,492   2,887   2,499   6,739  10,035
# 5    5,003   4,200   5,360   9,419   7,204
# 6      682     869     972   1,778   2,552
# 7    7,153   4,451   5,515   5,142   5,467
# 8    2,377   1,172   1,296   2,482   2,095
# 9   11,271   9,987   9,894  24,417  31,142
# 10   6,143   5,607   5,719  13,286  14,689
# 11  11,037  11,243  12,192  15,146  15,252
# 12     805   1,143   1,140   3,206   3,252
# 13  49,144  44,207  47,157  85,514  96,159
# 14     NaN     NaN     NaN     NaN     NaN
# 17       9      16      22      10      13
# 18       4      13      11       9      16
# 19     143     158     142     151     108
# 20      13      29      17      15      19
# 21       7       4       1       4       5
# 22       6       2       1       0       1
# 23      30      33      44      71      89

# %%
#Create a new column for province/region name
df['province_region'] = df['Occupational_Skill_Type'].where(df['2016'].isna() & ~df['Occupational_Skill_Type'].str.contains('Total', na=False))
#  Forward-fill the region name for all rows until a new region is found
df['province_region'] = df['province_region'].ffill()
#  Remove rows that contain "Total" adn Nan value (since these are summary rows)
df = df[~df['Occupational_Skill_Type'].str.contains('Total', na=False)]

# %%
df.head(20)
# Out:
#                               Occupational_Skill_Type   2016   2017   2018  \
# 0                                              Canada    NaN    NaN    NaN
# 3                         0 - Management occupations   1,834  1,701  1,452
# 4   1 - Business, finance and administration occup...  1,065  1,196  1,153
# 5   2 - Natural and applied sciences and related o...  3,350  3,238  3,465
# 6                             3 - Health occupations     617    478    401
# 7   4 - Occupations in education, law and social, ...  6,797  7,458  9,003
# 8   5 - Occupations in art, culture, recreation an...  4,132  2,777  2,378
# 9                  6 - Sales and service occupations   6,013  6,841  6,286
# 10  7 - Trades, transport and equipment operators ...  3,090  3,447  3,131
# 11  8 - Natural resources, agriculture and related...  8,332  8,344  9,430
# 12    9 - Occupations in manufacturing and utilities     249    344    403
# 14                          Newfoundland and Labrador    NaN    NaN    NaN
# 17                        0 - Management occupations      67     34     14
# 18  1 - Business, finance and administration occup...     14      6      5
# 19  2 - Natural and applied sciences and related o...    567    453     98
# 20                            3 - Health occupations      27     10      8
# 21  4 - Occupations in education, law and social, ...     25     13     11
# 22  5 - Occupations in art, culture, recreation an...     11      9      1
# 23                 6 - Sales and service occupations     117     77     29
# 24  7 - Trades, transport and equipment operators ...    371    350     84
#
#       2019    2020    2021    2022    2023            province_region
# 0      NaN     NaN     NaN     NaN     NaN                     Canada
# 3    2,180   2,646   2,569   3,894   4,460                     Canada
# 4    2,492   2,887   2,499   6,739  10,035                     Canada
# 5    5,003   4,200   5,360   9,419   7,204                     Canada
# 6      682     869     972   1,778   2,552                     Canada
# 7    7,153   4,451   5,515   5,142   5,467                     Canada
# 8    2,377   1,172   1,296   2,482   2,095                     Canada
# 9   11,271   9,987   9,894  24,417  31,142                     Canada
# 10   6,143   5,607   5,719  13,286  14,689                     Canada
# 11  11,037  11,243  12,192  15,146  15,252                     Canada
# 12     805   1,143   1,140   3,206   3,252                     Canada
# 14     NaN     NaN     NaN     NaN     NaN  Newfoundland and Labrador
# 17       9      16      22      10      13  Newfoundland and Labrador
# 18       4      13      11       9      16  Newfoundland and Labrador
# 19     143     158     142     151     108  Newfoundland and Labrador
# 20      13      29      17      15      19  Newfoundland and Labrador
# 21       7       4       1       4       5  Newfoundland and Labrador
# 22       6       2       1       0       1  Newfoundland and Labrador
# 23      30      33      44      71      89  Newfoundland and Labrador
# 24      73     179     101     154      78  Newfoundland and Labrador

# %%
df = df.dropna(how='any')

# %%
df.head(20)
# Out:
#                               Occupational_Skill_Type   2016   2017   2018  \
# 3                         0 - Management occupations   1,834  1,701  1,452
# 4   1 - Business, finance and administration occup...  1,065  1,196  1,153
# 5   2 - Natural and applied sciences and related o...  3,350  3,238  3,465
# 6                             3 - Health occupations     617    478    401
# 7   4 - Occupations in education, law and social, ...  6,797  7,458  9,003
# 8   5 - Occupations in art, culture, recreation an...  4,132  2,777  2,378
# 9                  6 - Sales and service occupations   6,013  6,841  6,286
# 10  7 - Trades, transport and equipment operators ...  3,090  3,447  3,131
# 11  8 - Natural resources, agriculture and related...  8,332  8,344  9,430
# 12    9 - Occupations in manufacturing and utilities     249    344    403
# 17                        0 - Management occupations      67     34     14
# 18  1 - Business, finance and administration occup...     14      6      5
# 19  2 - Natural and applied sciences and related o...    567    453     98
# 20                            3 - Health occupations      27     10      8
# 21  4 - Occupations in education, law and social, ...     25     13     11
# 22  5 - Occupations in art, culture, recreation an...     11      9      1
# 23                 6 - Sales and service occupations     117     77     29
# 24  7 - Trades, transport and equipment operators ...    371    350     84
# 25  8 - Natural resources, agriculture and related...     32     72     39
# 26    9 - Occupations in manufacturing and utilities       9      7      5
#
#       2019    2020    2021    2022    2023            province_region
# 3    2,180   2,646   2,569   3,894   4,460                     Canada
# 4    2,492   2,887   2,499   6,739  10,035                     Canada
# 5    5,003   4,200   5,360   9,419   7,204                     Canada
# 6      682     869     972   1,778   2,552                     Canada
# 7    7,153   4,451   5,515   5,142   5,467                     Canada
# 8    2,377   1,172   1,296   2,482   2,095                     Canada
# 9   11,271   9,987   9,894  24,417  31,142                     Canada
# 10   6,143   5,607   5,719  13,286  14,689                     Canada
# 11  11,037  11,243  12,192  15,146  15,252                     Canada
# 12     805   1,143   1,140   3,206   3,252                     Canada
# 17       9      16      22      10      13  Newfoundland and Labrador
# 18       4      13      11       9      16  Newfoundland and Labrador
# 19     143     158     142     151     108  Newfoundland and Labrador
# 20      13      29      17      15      19  Newfoundland and Labrador
# 21       7       4       1       4       5  Newfoundland and Labrador
# 22       6       2       1       0       1  Newfoundland and Labrador
# 23      30      33      44      71      89  Newfoundland and Labrador
# 24      73     179     101     154      78  Newfoundland and Labrador
# 25      33      40      43      83     115  Newfoundland and Labrador
# 26       5       5       4      27      27  Newfoundland and Labrador

# %%
#Create new columns for skill level  and Occupational code  seperatelly
df[['Skill_Type','Occupation']] = df['Occupational_Skill_Type'].str.extract(r'(\w+) - (.*)')
# Drop the original column after splitting
df = df.drop(columns=['Occupational_Skill_Type'])

# %%
df.head(20)
# Out:
#      2016   2017   2018    2019    2020    2021    2022    2023  \
# 3   1,834  1,701  1,452   2,180   2,646   2,569   3,894   4,460
# 4   1,065  1,196  1,153   2,492   2,887   2,499   6,739  10,035
# 5   3,350  3,238  3,465   5,003   4,200   5,360   9,419   7,204
# 6     617    478    401     682     869     972   1,778   2,552
# 7   6,797  7,458  9,003   7,153   4,451   5,515   5,142   5,467
# 8   4,132  2,777  2,378   2,377   1,172   1,296   2,482   2,095
# 9   6,013  6,841  6,286  11,271   9,987   9,894  24,417  31,142
# 10  3,090  3,447  3,131   6,143   5,607   5,719  13,286  14,689
# 11  8,332  8,344  9,430  11,037  11,243  12,192  15,146  15,252
# 12    249    344    403     805   1,143   1,140   3,206   3,252
# 17     67     34     14       9      16      22      10      13
# 18     14      6      5       4      13      11       9      16
# 19    567    453     98     143     158     142     151     108
# 20     27     10      8      13      29      17      15      19
# 21     25     13     11       7       4       1       4       5
# 22     11      9      1       6       2       1       0       1
# 23    117     77     29      30      33      44      71      89
# 24    371    350     84      73     179     101     154      78
# 25     32     72     39      33      40      43      83     115
# 26      9      7      5       5       5       4      27      27
#
#               province_region Skill_Type  \
# 3                      Canada          0
# 4                      Canada          1
# 5                      Canada          2
# 6                      Canada          3
# 7                      Canada          4
# 8                      Canada          5
# 9                      Canada          6
# 10                     Canada          7
# 11                     Canada          8
# 12                     Canada          9
# 17  Newfoundland and Labrador          0
# 18  Newfoundland and Labrador          1
# 19  Newfoundland and Labrador          2
# 20  Newfoundland and Labrador          3
# 21  Newfoundland and Labrador          4
# 22  Newfoundland and Labrador          5
# 23  Newfoundland and Labrador          6
# 24  Newfoundland and Labrador          7
# 25  Newfoundland and Labrador          8
# 26  Newfoundland and Labrador          9
#
#                                            Occupation
# 3                             Management occupations
# 4   Business, finance and administration occupations
# 5   Natural and applied sciences and related occup...
# 6                                 Health occupations
# 7   Occupations in education, law and social, comm...
# 8   Occupations in art, culture, recreation and sp...
# 9                      Sales and service occupations
# 10  Trades, transport and equipment operators and ...
# 11  Natural resources, agriculture and related pro...
# 12        Occupations in manufacturing and utilities
# 17                            Management occupations
# 18  Business, finance and administration occupations
# 19  Natural and applied sciences and related occup...
# 20                                Health occupations
# 21  Occupations in education, law and social, comm...
# 22  Occupations in art, culture, recreation and sp...
# 23                     Sales and service occupations
# 24  Trades, transport and equipment operators and ...
# 25  Natural resources, agriculture and related pro...
# 26        Occupations in manufacturing and utilities

# %%
# Define the desired column order
desired_order = ['province_region', 'Occupation','Skill_Type', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
# Reorder the DataFrame using the desired column order
df = df[desired_order]

# %%
df
# Out:
#     province_region                                         Occupation  \
# 3            Canada                            Management occupations
# 4            Canada  Business, finance and administration occupations
# 5            Canada  Natural and applied sciences and related occup...
# 6            Canada                                Health occupations
# 7            Canada  Occupations in education, law and social, comm...
# ..              ...                                                ...
# 190         Nunavut  Occupations in art, culture, recreation and sp...
# 191         Nunavut                     Sales and service occupations
# 192         Nunavut  Trades, transport and equipment operators and ...
# 193         Nunavut  Natural resources, agriculture and related pro...
# 194         Nunavut        Occupations in manufacturing and utilities
#
#     Skill_Type   2016   2017   2018   2019   2020   2021   2022    2023
# 3            0  1,834  1,701  1,452  2,180  2,646  2,569  3,894   4,460
# 4            1  1,065  1,196  1,153  2,492  2,887  2,499  6,739  10,035
# 5            2  3,350  3,238  3,465  5,003  4,200  5,360  9,419   7,204
# 6            3    617    478    401    682    869    972  1,778   2,552
# 7            4  6,797  7,458  9,003  7,153  4,451  5,515  5,142   5,467
# ..         ...    ...    ...    ...    ...    ...    ...    ...     ...
# 190          5      7      1      6      1      0      2      0       0
# 191          6     83     15     38     33      4      6     21      29
# 192          7     15      2     19     16      7     21      8      28
# 193          8      0      0      0      0      0      0      0       0
# 194          9      0      0      0      0      0      0      0       0
#
# [140 rows x 11 columns]

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#     province_region                                         Occupation  \
# 0            Canada                            Management occupations
# 1            Canada  Business, finance and administration occupations
# 2            Canada  Natural and applied sciences and related occup...
# 3            Canada                                Health occupations
# 4            Canada  Occupations in education, law and social, comm...
# ..              ...                                                ...
# 135         Nunavut  Occupations in art, culture, recreation and sp...
# 136         Nunavut                     Sales and service occupations
# 137         Nunavut  Trades, transport and equipment operators and ...
# 138         Nunavut  Natural resources, agriculture and related pro...
# 139         Nunavut        Occupations in manufacturing and utilities
#
#     Skill_Type   2016   2017   2018   2019   2020   2021   2022    2023
# 0            0  1,834  1,701  1,452  2,180  2,646  2,569  3,894   4,460
# 1            1  1,065  1,196  1,153  2,492  2,887  2,499  6,739  10,035
# 2            2  3,350  3,238  3,465  5,003  4,200  5,360  9,419   7,204
# 3            3    617    478    401    682    869    972  1,778   2,552
# 4            4  6,797  7,458  9,003  7,153  4,451  5,515  5,142   5,467
# ..         ...    ...    ...    ...    ...    ...    ...    ...     ...
# 135          5      7      1      6      1      0      2      0       0
# 136          6     83     15     38     33      4      6     21      29
# 137          7     15      2     19     16      7     21      8      28
# 138          8      0      0      0      0      0      0      0       0
# 139          9      0      0      0      0      0      0      0       0
#
# [140 rows x 11 columns]

# %%
#Define the dedicated folder path
folder_path = 'C:/Users/Johnn/Desktop/Data Engineer project/LMIA_evaluation_project/clean_data'
csv_file = os.path.join(folder_path, 'Table21_Unique_Employers_Positive_LMIAs_By_NAICS_Province_2016_2023_cleaned.csv')

# Save the DataFrame to CSV
df.to_csv(csv_file, index=False)
