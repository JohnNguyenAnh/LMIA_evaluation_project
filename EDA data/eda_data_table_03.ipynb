# %%
import pandas as pd
import os

# %%
#import table file
df = pd.read_csv(r'../raw_data/Table03_TFW_Positive_LMIAs_By_EconomicRegion_Province_2016_2023.csv', encoding='ISO-8859-1', skiprows=1)
df.head()
# Out:
#                           Newfoundland and Labrador Unnamed: 1 Unnamed: 2  \
# 0                                   Economic Region       2016       2017
# 1                          1010 - Avalon Peninsula         219        144
# 2              1020 - South Coast--Burin Peninsula           1          9
# 3  1030 - West Coast--Northern Peninsula--Labrador          49         34
# 4         1040 - Notre Dame--Central Bonavista Bay          18         12
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0       2018       2019       2020       2021       2022       2023
# 1        152        101         79         74        583        840
# 2          4          3          2          4         36         61
# 3         56         39         45         53        108        151
# 4          7         40         38         59        153        162

# %%
df = df.iloc[:-11]
df
# Out:
#                             Newfoundland and Labrador Unnamed: 1 Unnamed: 2  \
# 0                                     Economic Region       2016       2017
# 1                            1010 - Avalon Peninsula         219        144
# 2                1020 - South Coast--Burin Peninsula           1          9
# 3    1030 - West Coast--Northern Peninsula--Labrador          49         34
# 4           1040 - Notre Dame--Central Bonavista Bay          18         12
# ..                                                ...        ...        ...
# 118                     Northwest Territories - Total         64         46
# 119                                           Nunavut        NaN        NaN
# 120                                   Economic Region       2016       2017
# 121                                   6210 - Nunavut         145         41
# 122                                   Nunavut - Total        145         41
#
# ...

# %%
df.sample(10)
# Out:
#        Newfoundland and Labrador Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 23   1320 - Moncton--Richibucto         857      1,275        833      1,132
# 52                3510 - Ottawa         722        715        832        859
# 94              4860 - Edmonton       3,300      2,822      2,563      4,210
# 63                        Other         124        193        518        212
# 109                       Other         410        402        310        371
# 93              4850 - Red Deer         395        442        456        507
# 37            2435 - Montérégie       8,075      6,178      6,880     11,078
# 115        Northwest Territories        NaN        NaN        NaN        NaN
# 114                Yukon - Total        107        119        107        139
# 29                        Quebec        NaN        NaN        NaN        NaN
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8
# 23       2,106      1,574      4,588      2,882
# ...
